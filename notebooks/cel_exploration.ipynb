# %% [markdown]
# # I. Introduction
#
# ### Définition du problème
#
# L'objectif du projet est de développer un modèle de classification de
# produits e-commerce Rakuten capable de prédire un code type de
# produit à partir de données multimodales :
# - textes(catégories et description produits),
# - images associées.
#
# Cette classification est utile pour :
# - exploiter efficacement le contenu fourni par les vendeurs,
# - éviter les doublons,
# - faciliter la gestion du catalogue,
# - améliorer la recommandation et la personnalisation du parcours
# utilisateur.
#
# Le projet s'inscrit dans le cadre du challenge :
# **https://challengedata.ens.fr/challenges/35**
#
#
#
# ### Description du jeu des données
#
# Les données sont composées de :
#
# • Fichiers CSV
#
# -   **X_train.csv** : données d'entraînement (84 916 produits)
# -   **Y_train.csv** : labels associés
# -   **X_test.csv** : données de test (13 812 produits)
#
#
# • Images
#
# Un dossier compressé qui contient :
# - **image_training**
# - **image_test**
#
# ### Présentation détaillée des variables
#
# | ID | Nom de la colonne | Description                           | Disponibilité | Type  | Taux de NA (%) | Gestion NA                           | Remarques                                                                            |
# | -- | ----------------- | ------------------------------------- | ------------- | ----- | -------------- | ------------------------------------ | ------------------------------------------------------------------------------------ |
# | 1  | **ID**            | Identifiant du produit (jointure X/Y) | Oui           | Int64 | 0              | —                                    | —                                                                                    |
# | 2  | **designation**   | Titre du produit                      | Oui           | Objet | 0              | —                                    | Large variété de catégories (livres, jeux vidéo, jouets, éclairage, jardinage, etc.) |
# | 3  | **description**   | Description du produit                | Oui           | Objet | 35.37          | Suppression  | Texte très hétérogène et bruité                                                      |
# | 4  | **productId**     | Identifiant unique du produit         | Oui           | Int64 | 0              | —                                    | Redondant avec ID                                                          |
# | 5  | **imageId**       | Identifiant unique de l’image         | Oui           | Int64 | 0              | —                                    | Toutes les images ont les mêmes dimensions                                           |
#
# ### Structure du dataset
#
# -   Données multimodales : texte + image
# -   Données bruitées
# -   Classes nombreuses (27)
# -   Taille importante (près de 90 000 produits)
