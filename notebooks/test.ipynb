# %%
import sys

sys.path.insert(0, '../src')

from rakuten_text import text_preprocess
from data import split_path

# %%
text_preprocess("objet datant de 10/12/2018. Histoire se passant en 2042.... ")
# Out:
# 'objet datant de  ( date récente ) . Histoire se passant en  ( date future ) ....'

# %%
help(split_path)
# Out:
# Help on function split_path in module data.load_data:
#
# split_path()
#     retourne les chemins des images splités entre le jeu de test utilisé pour ce projet
#     et le jeu d'entraintement / validation

# %%
a
# Out:
# 46159    C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
# 8198     C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
# 49707    C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
# 83740    C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
# 7312     C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
#                                ...
# 81419    C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
# 2509     C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
# 56768    C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
# 82324    C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
# 43770    C:\Users\gabyd\Documents\GitHub\DS_rakuten_com...
# Length: 72178, dtype: object

# %%
a,b,c,d = split_path()
